# %%
import pandas as pd

# %%
base = pd.read_csv('student-por.csv')
base.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
base.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %%
base = base.drop('school',axis=1)
base.head(10)
# Out:
#   sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0   F   18       U     GT3       A     4     4   at_home   teacher
# 1   F   17       U     GT3       T     1     1   at_home     other
# 2   F   15       U     LE3       T     1     1   at_home     other
# 3   F   15       U     GT3       T     4     2    health  services
# 4   F   16       U     GT3       T     3     3     other     other
# 5   M   16       U     LE3       T     4     3  services     other
# 6   M   16       U     LE3       T     2     2     other     other
# 7   F   17       U     GT3       A     4     4     other   teacher
# 8   M   15       U     LE3       A     3     2  services     other
# 9   M   15       U     GT3       T     3     4     other     other
#
#        reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  G2  \
# 0      course  ...      4         3      4     1    1      3        4   0  11
# ...

# %%
base = base.drop('sex',axis=1)
base.head(10)
# Out:
#    age address famsize Pstatus  Medu  Fedu      Mjob      Fjob      reason  \
# 0   18       U     GT3       A     4     4   at_home   teacher      course
# 1   17       U     GT3       T     1     1   at_home     other      course
# 2   15       U     LE3       T     1     1   at_home     other       other
# 3   15       U     GT3       T     4     2    health  services        home
# 4   16       U     GT3       T     3     3     other     other        home
# 5   16       U     LE3       T     4     3  services     other  reputation
# 6   16       U     LE3       T     2     2     other     other        home
# 7   17       U     GT3       A     4     4     other   teacher        home
# 8   15       U     LE3       A     3     2  services     other        home
# 9   15       U     GT3       T     3     4     other     other        home
#
#   guardian  ...  famrel  freetime  goout Dalc Walc health absences  G1  G2  G3
# ...

# %%
base = base.drop('age',axis=1)
base.head(10)
# Out:
#   address famsize Pstatus  Medu  Fedu      Mjob      Fjob      reason  \
# 0       U     GT3       A     4     4   at_home   teacher      course
# 1       U     GT3       T     1     1   at_home     other      course
# 2       U     LE3       T     1     1   at_home     other       other
# 3       U     GT3       T     4     2    health  services        home
# 4       U     GT3       T     3     3     other     other        home
# 5       U     LE3       T     4     3  services     other  reputation
# 6       U     LE3       T     2     2     other     other        home
# 7       U     GT3       A     4     4     other   teacher        home
# 8       U     LE3       A     3     2  services     other        home
# 9       U     GT3       T     3     4     other     other        home
#
#   guardian  traveltime  ...  famrel  freetime goout Dalc Walc health absences  \
# 0   mother           2  ...       4         3     4    1    1      3        4
# ...

# %%
base = base.drop('address',axis=1)
base.head(10)
# Out:
#   famsize Pstatus  Medu  Fedu      Mjob      Fjob      reason guardian  \
# 0     GT3       A     4     4   at_home   teacher      course   mother
# 1     GT3       T     1     1   at_home     other      course   father
# 2     LE3       T     1     1   at_home     other       other   mother
# 3     GT3       T     4     2    health  services        home   mother
# 4     GT3       T     3     3     other     other        home   father
# 5     LE3       T     4     3  services     other  reputation   mother
# 6     LE3       T     2     2     other     other        home   mother
# 7     GT3       A     4     4     other   teacher        home   mother
# 8     LE3       A     3     2  services     other        home   mother
# 9     GT3       T     3     4     other     other        home   mother
#
#    traveltime  studytime  ...  famrel freetime goout Dalc Walc health  \
# 0           2          2  ...       4        3     4    1    1      3
# ...

# %%
base = base.drop('famsize',axis=1)
base.head(10)
# Out:
#   Pstatus  Medu  Fedu      Mjob      Fjob      reason guardian  traveltime  \
# 0       A     4     4   at_home   teacher      course   mother           2
# 1       T     1     1   at_home     other      course   father           1
# 2       T     1     1   at_home     other       other   mother           1
# 3       T     4     2    health  services        home   mother           1
# 4       T     3     3     other     other        home   father           1
# 5       T     4     3  services     other  reputation   mother           1
# 6       T     2     2     other     other        home   mother           1
# 7       A     4     4     other   teacher        home   mother           2
# 8       A     3     2  services     other        home   mother           1
# 9       T     3     4     other     other        home   mother           1
#
#    studytime  failures  ... famrel freetime goout Dalc Walc health absences  \
# ...

# %%
base = base.drop('Pstatus',axis=1)
base.head(10)
# Out:
#    Medu  Fedu      Mjob      Fjob      reason guardian  traveltime  studytime  \
# 0     4     4   at_home   teacher      course   mother           2          2
# 1     1     1   at_home     other      course   father           1          2
# 2     1     1   at_home     other       other   mother           1          2
# 3     4     2    health  services        home   mother           1          3
# 4     3     3     other     other        home   father           1          2
# 5     4     3  services     other  reputation   mother           1          2
# 6     2     2     other     other        home   mother           1          2
# 7     4     4     other   teacher        home   mother           2          2
# 8     3     2  services     other        home   mother           1          2
# 9     3     4     other     other        home   mother           1          2
#
#    failures schoolsup  ... famrel freetime goout Dalc Walc health absences  \
# ...

# %%
base = base.drop('Medu',axis=1)
base.head(10)
# Out:
#    Fedu      Mjob      Fjob      reason guardian  traveltime  studytime  \
# 0     4   at_home   teacher      course   mother           2          2
# 1     1   at_home     other      course   father           1          2
# 2     1   at_home     other       other   mother           1          2
# 3     2    health  services        home   mother           1          3
# 4     3     other     other        home   father           1          2
# 5     3  services     other  reputation   mother           1          2
# 6     2     other     other        home   mother           1          2
# 7     4     other   teacher        home   mother           2          2
# 8     2  services     other        home   mother           1          2
# 9     4     other     other        home   mother           1          2
#
#    failures schoolsup famsup  ... famrel freetime goout Dalc Walc health  \
# 0         0       yes     no  ...      4        3     4    1    1      3
# ...

# %%
base = base.drop('Fedu',axis=1)
base.head(10)
# Out:
#        Mjob      Fjob      reason guardian  traveltime  studytime  failures  \
# 0   at_home   teacher      course   mother           2          2         0
# 1   at_home     other      course   father           1          2         0
# 2   at_home     other       other   mother           1          2         0
# 3    health  services        home   mother           1          3         0
# 4     other     other        home   father           1          2         0
# 5  services     other  reputation   mother           1          2         0
# 6     other     other        home   mother           1          2         0
# 7     other   teacher        home   mother           2          2         0
# 8  services     other        home   mother           1          2         0
# 9     other     other        home   mother           1          2         0
#
#   schoolsup famsup paid  ... famrel freetime goout Dalc Walc  health  \
# ...

# %%
base['Mjob'].value_counts()
# Out:
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: Mjob, dtype: int64

# %%
base['Mjob'] = base['Mjob'].replace('other', 0)
base['Mjob'] = base['Mjob'].replace('services', 1)
base['Mjob'] = base['Mjob'].replace('at_home', 2)
base['Mjob'] = base['Mjob'].replace('teacher', 3)
base['Mjob'] = base['Mjob'].replace('health', 4)

base.head(10)
# Out:
#    Mjob      Fjob      reason guardian  traveltime  studytime  failures  \
# 0     2   teacher      course   mother           2          2         0
# 1     2     other      course   father           1          2         0
# 2     2     other       other   mother           1          2         0
# 3     4  services        home   mother           1          3         0
# 4     0     other        home   father           1          2         0
# 5     1     other  reputation   mother           1          2         0
# 6     0     other        home   mother           1          2         0
# 7     0   teacher        home   mother           2          2         0
# 8     1     other        home   mother           1          2         0
# 9     0     other        home   mother           1          2         0
#
#   schoolsup famsup paid  ... famrel freetime goout Dalc Walc  health  \
# 0       yes     no   no  ...      4        3     4    1    1       3
# ...

# %%
base['Fjob'].value_counts()
# Out:
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: Fjob, dtype: int64

# %%
base['Fjob'] = base['Fjob'].replace('other', 0)
base['Fjob'] = base['Fjob'].replace('services', 1)
base['Fjob'] = base['Fjob'].replace('at_home', 2)
base['Fjob'] = base['Fjob'].replace('teacher', 3)
base['Fjob'] = base['Fjob'].replace('health', 4)

base.head(10)
# Out:
#    Mjob  Fjob      reason guardian  traveltime  studytime  failures schoolsup  \
# 0     2     3      course   mother           2          2         0       yes
# 1     2     0      course   father           1          2         0        no
# 2     2     0       other   mother           1          2         0       yes
# 3     4     1        home   mother           1          3         0        no
# 4     0     0        home   father           1          2         0        no
# 5     1     0  reputation   mother           1          2         0        no
# 6     0     0        home   mother           1          2         0        no
# 7     0     3        home   mother           2          2         0       yes
# 8     1     0        home   mother           1          2         0        no
# 9     0     0        home   mother           1          2         0        no
#
#   famsup paid  ... famrel freetime goout Dalc Walc  health  absences  G1  G2  \
# ...

# %%
base = base.drop('reason',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0     2     3   mother           2          2         0       yes     no   no
# 1     2     0   father           1          2         0        no    yes   no
# 2     2     0   mother           1          2         0       yes     no   no
# 3     4     1   mother           1          3         0        no    yes   no
# 4     0     0   father           1          2         0        no    yes   no
# 5     1     0   mother           1          2         0        no    yes   no
# 6     0     0   mother           1          2         0        no     no   no
# 7     0     3   mother           2          2         0       yes    yes   no
# 8     1     0   mother           1          2         0        no    yes   no
# 9     0     0   mother           1          2         0        no    yes   no
#
#   activities  ... famrel freetime goout Dalc  Walc  health  absences  G1  G2  \
# ...

# %%
base = base.drop('guardian',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures schoolsup famsup paid  \
# 0     2     3           2          2         0       yes     no   no
# 1     2     0           1          2         0        no    yes   no
# 2     2     0           1          2         0       yes     no   no
# 3     4     1           1          3         0        no    yes   no
# 4     0     0           1          2         0        no    yes   no
# 5     1     0           1          2         0        no    yes   no
# 6     0     0           1          2         0        no     no   no
# 7     0     3           2          2         0       yes    yes   no
# 8     1     0           1          2         0        no    yes   no
# 9     0     0           1          2         0        no    yes   no
#
#   activities nursery  ... famrel freetime goout  Dalc  Walc  health  absences  \
# 0         no     yes  ...      4        3     4     1     1       3         4
# ...

# %%
base = base.drop('schoolsup',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures famsup paid activities nursery  \
# 0     2     3           2          2         0     no   no         no     yes
# 1     2     0           1          2         0    yes   no         no      no
# 2     2     0           1          2         0     no   no         no     yes
# 3     4     1           1          3         0    yes   no        yes     yes
# 4     0     0           1          2         0    yes   no         no     yes
# 5     1     0           1          2         0    yes   no        yes     yes
# 6     0     0           1          2         0     no   no         no     yes
# 7     0     3           2          2         0    yes   no         no     yes
# 8     1     0           1          2         0    yes   no         no     yes
# 9     0     0           1          2         0    yes   no        yes     yes
#
#   higher  ... famrel freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# ...

# %%
base = base.drop('famsup',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures paid activities nursery higher  \
# 0     2     3           2          2         0   no         no     yes    yes
# 1     2     0           1          2         0   no         no      no    yes
# 2     2     0           1          2         0   no         no     yes    yes
# 3     4     1           1          3         0   no        yes     yes    yes
# 4     0     0           1          2         0   no         no     yes    yes
# 5     1     0           1          2         0   no        yes     yes    yes
# 6     0     0           1          2         0   no         no     yes    yes
# 7     0     3           2          2         0   no         no     yes    yes
# 8     1     0           1          2         0   no         no     yes    yes
# 9     0     0           1          2         0   no        yes     yes    yes
#
#   internet  ... famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  \
# ...

# %%
base = base.drop('paid',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures activities nursery higher  \
# 0     2     3           2          2         0         no     yes    yes
# 1     2     0           1          2         0         no      no    yes
# 2     2     0           1          2         0         no     yes    yes
# 3     4     1           1          3         0        yes     yes    yes
# 4     0     0           1          2         0         no     yes    yes
# 5     1     0           1          2         0        yes     yes    yes
# 6     0     0           1          2         0         no     yes    yes
# 7     0     3           2          2         0         no     yes    yes
# 8     1     0           1          2         0         no     yes    yes
# 9     0     0           1          2         0        yes     yes    yes
#
#   internet romantic  famrel  freetime  goout  Dalc  Walc  health  absences  \
# 0       no       no       4         3      4     1     1       3         4
# ...

# %%
base = base.drop('activities',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures nursery higher internet  \
# 0     2     3           2          2         0     yes    yes       no
# 1     2     0           1          2         0      no    yes      yes
# 2     2     0           1          2         0     yes    yes      yes
# 3     4     1           1          3         0     yes    yes      yes
# 4     0     0           1          2         0     yes    yes       no
# 5     1     0           1          2         0     yes    yes      yes
# 6     0     0           1          2         0     yes    yes      yes
# 7     0     3           2          2         0     yes    yes       no
# 8     1     0           1          2         0     yes    yes      yes
# 9     0     0           1          2         0     yes    yes      yes
#
#   romantic  famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       no       4         3      4     1     1       3         4   0  11  11
# ...

# %%
base = base.drop('nursery',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures higher internet romantic  \
# 0     2     3           2          2         0    yes       no       no
# 1     2     0           1          2         0    yes      yes       no
# 2     2     0           1          2         0    yes      yes       no
# 3     4     1           1          3         0    yes      yes      yes
# 4     0     0           1          2         0    yes       no       no
# 5     1     0           1          2         0    yes      yes       no
# 6     0     0           1          2         0    yes      yes       no
# 7     0     3           2          2         0    yes       no       no
# 8     1     0           1          2         0    yes      yes       no
# 9     0     0           1          2         0    yes      yes       no
#
#    famrel  freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0       4         3      4     1     1       3         4   0  11  11
# ...

# %%
base = base.drop('higher',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures internet romantic  famrel  \
# 0     2     3           2          2         0       no       no       4
# 1     2     0           1          2         0      yes       no       5
# 2     2     0           1          2         0      yes       no       4
# 3     4     1           1          3         0      yes      yes       3
# 4     0     0           1          2         0       no       no       4
# 5     1     0           1          2         0      yes       no       5
# 6     0     0           1          2         0      yes       no       4
# 7     0     3           2          2         0       no       no       4
# 8     1     0           1          2         0      yes       no       4
# 9     0     0           1          2         0      yes       no       5
#
#    freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         3      4     1     1       3         4   0  11  11
# ...

# %%
base['internet'] = base['internet'].replace('no', 0)
base['internet'] = base['internet'].replace('yes', 1)

base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet romantic  famrel  \
# 0     2     3           2          2         0         0       no       4
# 1     2     0           1          2         0         1       no       5
# 2     2     0           1          2         0         1       no       4
# 3     4     1           1          3         0         1      yes       3
# 4     0     0           1          2         0         0       no       4
# 5     1     0           1          2         0         1       no       5
# 6     0     0           1          2         0         1       no       4
# 7     0     3           2          2         0         0       no       4
# 8     1     0           1          2         0         1       no       4
# 9     0     0           1          2         0         1       no       5
#
#    freetime  goout  Dalc  Walc  health  absences  G1  G2  G3
# 0         3      4     1     1       3         4   0  11  11
# ...

# %%
base = base.drop('romantic',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  famrel  freetime  \
# 0     2     3           2          2         0         0       4         3
# 1     2     0           1          2         0         1       5         3
# 2     2     0           1          2         0         1       4         3
# 3     4     1           1          3         0         1       3         2
# 4     0     0           1          2         0         0       4         3
# 5     1     0           1          2         0         1       5         4
# 6     0     0           1          2         0         1       4         4
# 7     0     3           2          2         0         0       4         1
# 8     1     0           1          2         0         1       4         2
# 9     0     0           1          2         0         1       5         5
#
#    goout  Dalc  Walc  health  absences  G1  G2  G3
# 0      4     1     1       3         4   0  11  11
# ...

# %%
base = base.drop('famrel',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  goout  \
# 0     2     3           2          2         0         0         3      4
# 1     2     0           1          2         0         1         3      3
# 2     2     0           1          2         0         1         3      2
# 3     4     1           1          3         0         1         2      2
# 4     0     0           1          2         0         0         3      2
# 5     1     0           1          2         0         1         4      2
# 6     0     0           1          2         0         1         4      4
# 7     0     3           2          2         0         0         1      4
# 8     1     0           1          2         0         1         2      2
# 9     0     0           1          2         0         1         5      1
#
#    Dalc  Walc  health  absences  G1  G2  G3
# 0     1     1       3         4   0  11  11
# 1     1     1       3         2   9  11  11
# ...

# %%
base = base.drop('goout',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  Dalc  \
# 0     2     3           2          2         0         0         3     1
# 1     2     0           1          2         0         1         3     1
# 2     2     0           1          2         0         1         3     2
# 3     4     1           1          3         0         1         2     1
# 4     0     0           1          2         0         0         3     1
# 5     1     0           1          2         0         1         4     1
# 6     0     0           1          2         0         1         4     1
# 7     0     3           2          2         0         0         1     1
# 8     1     0           1          2         0         1         2     1
# 9     0     0           1          2         0         1         5     1
#
#    Walc  health  absences  G1  G2  G3
# 0     1       3         4   0  11  11
# 1     1       3         2   9  11  11
# 2     3       3         6  12  13  12
# ...

# %%
base = base.drop('Dalc',axis=1)
base = base.drop('Walc',axis=1)
base = base.drop('health',axis=1)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0     2     3           2          2         0         0         3         4
# 1     2     0           1          2         0         1         3         2
# 2     2     0           1          2         0         1         3         6
# 3     4     1           1          3         0         1         2         0
# 4     0     0           1          2         0         0         3         0
# 5     1     0           1          2         0         1         4         6
# 6     0     0           1          2         0         1         4         0
# 7     0     3           2          2         0         0         1         2
# 8     1     0           1          2         0         1         2         0
# 9     0     0           1          2         0         1         5         0
#
#    G1  G2  G3
# 0   0  11  11
# 1   9  11  11
# 2  12  13  12
# 3  14  14  14
# 4  11  13  13
# 5  12  12  13
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Mjob        649 non-null    int64
#  1   Fjob        649 non-null    int64
#  2   traveltime  649 non-null    int64
#  3   studytime   649 non-null    int64
#  4   failures    649 non-null    int64
#  5   internet    649 non-null    int64
#  6   freetime    649 non-null    int64
#  7   absences    649 non-null    int64
#  8   G1          649 non-null    int64
#  9   G2          649 non-null    int64
#  10  G3          649 non-null    int64
# dtypes: int64(11)
# memory usage: 55.9 KB

# %%
base['Average'] = (base['G1'] + base['G2'] + base['G3']) / 3 
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0     2     3           2          2         0         0         3         4
# 1     2     0           1          2         0         1         3         2
# 2     2     0           1          2         0         1         3         6
# 3     4     1           1          3         0         1         2         0
# 4     0     0           1          2         0         0         3         0
# 5     1     0           1          2         0         1         4         6
# 6     0     0           1          2         0         1         4         0
# 7     0     3           2          2         0         0         1         2
# 8     1     0           1          2         0         1         2         0
# 9     0     0           1          2         0         1         5         0
#
#    G1  G2  G3    Average
# 0   0  11  11   7.333333
# 1   9  11  11  10.333333
# 2  12  13  12  12.333333
# ...

# %%
base = base.astype(int).astype(float)
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0   2.0   3.0         2.0        2.0       0.0       0.0       3.0       4.0
# 1   2.0   0.0         1.0        2.0       0.0       1.0       3.0       2.0
# 2   2.0   0.0         1.0        2.0       0.0       1.0       3.0       6.0
# 3   4.0   1.0         1.0        3.0       0.0       1.0       2.0       0.0
# 4   0.0   0.0         1.0        2.0       0.0       0.0       3.0       0.0
# 5   1.0   0.0         1.0        2.0       0.0       1.0       4.0       6.0
# 6   0.0   0.0         1.0        2.0       0.0       1.0       4.0       0.0
# 7   0.0   3.0         2.0        2.0       0.0       0.0       1.0       2.0
# 8   1.0   0.0         1.0        2.0       0.0       1.0       2.0       0.0
# 9   0.0   0.0         1.0        2.0       0.0       1.0       5.0       0.0
#
#      G1    G2    G3  Average
# 0   0.0  11.0  11.0      7.0
# 1   9.0  11.0  11.0     10.0
# 2  12.0  13.0  12.0     12.0
# ...

# %%
base.loc[(base.Average >= 15.0),'approved'] = 1
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0   2.0   3.0         2.0        2.0       0.0       0.0       3.0       4.0
# 1   2.0   0.0         1.0        2.0       0.0       1.0       3.0       2.0
# 2   2.0   0.0         1.0        2.0       0.0       1.0       3.0       6.0
# 3   4.0   1.0         1.0        3.0       0.0       1.0       2.0       0.0
# 4   0.0   0.0         1.0        2.0       0.0       0.0       3.0       0.0
# 5   1.0   0.0         1.0        2.0       0.0       1.0       4.0       6.0
# 6   0.0   0.0         1.0        2.0       0.0       1.0       4.0       0.0
# 7   0.0   3.0         2.0        2.0       0.0       0.0       1.0       2.0
# 8   1.0   0.0         1.0        2.0       0.0       1.0       2.0       0.0
# 9   0.0   0.0         1.0        2.0       0.0       1.0       5.0       0.0
#
#      G1    G2    G3  Average  approved
# 0   0.0  11.0  11.0      7.0       NaN
# 1   9.0  11.0  11.0     10.0       NaN
# ...

# %%
base.loc[(base.Average < 15.0),'approved'] = 0
base.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0   2.0   3.0         2.0        2.0       0.0       0.0       3.0       4.0
# 1   2.0   0.0         1.0        2.0       0.0       1.0       3.0       2.0
# 2   2.0   0.0         1.0        2.0       0.0       1.0       3.0       6.0
# 3   4.0   1.0         1.0        3.0       0.0       1.0       2.0       0.0
# 4   0.0   0.0         1.0        2.0       0.0       0.0       3.0       0.0
# 5   1.0   0.0         1.0        2.0       0.0       1.0       4.0       6.0
# 6   0.0   0.0         1.0        2.0       0.0       1.0       4.0       0.0
# 7   0.0   3.0         2.0        2.0       0.0       0.0       1.0       2.0
# 8   1.0   0.0         1.0        2.0       0.0       1.0       2.0       0.0
# 9   0.0   0.0         1.0        2.0       0.0       1.0       5.0       0.0
#
#      G1    G2    G3  Average  approved
# 0   0.0  11.0  11.0      7.0       0.0
# 1   9.0  11.0  11.0     10.0       0.0
# ...

# %%
base.tail(10)
# Out:
#      Mjob  Fjob  traveltime  studytime  failures  internet  freetime  \
# 639   0.0   1.0         2.0        1.0       1.0       0.0       3.0
# 640   0.0   0.0         2.0        1.0       1.0       0.0       4.0
# 641   2.0   0.0         2.0        3.0       0.0       0.0       3.0
# 642   3.0   0.0         2.0        2.0       0.0       1.0       5.0
# 643   3.0   2.0         3.0        1.0       0.0       1.0       4.0
# 644   1.0   0.0         1.0        3.0       1.0       1.0       4.0
# 645   3.0   1.0         1.0        2.0       0.0       1.0       3.0
# 646   0.0   0.0         2.0        2.0       0.0       0.0       1.0
# 647   1.0   1.0         2.0        1.0       0.0       1.0       4.0
# 648   1.0   0.0         3.0        1.0       0.0       1.0       4.0
#
#      absences    G1    G2    G3  Average  approved
# 639       0.0   5.0   8.0   0.0      4.0       0.0
# 640       0.0   7.0   7.0   0.0      4.0       0.0
# 641       0.0  14.0  17.0  15.0     15.0       1.0
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression

# %%
teste = pd.read_csv('student-por.csv')
teste = base
teste.head(10)
# Out:
#    Mjob  Fjob  traveltime  studytime  failures  internet  freetime  absences  \
# 0   2.0   3.0         2.0        2.0       0.0       0.0       3.0       4.0
# 1   2.0   0.0         1.0        2.0       0.0       1.0       3.0       2.0
# 2   2.0   0.0         1.0        2.0       0.0       1.0       3.0       6.0
# 3   4.0   1.0         1.0        3.0       0.0       1.0       2.0       0.0
# 4   0.0   0.0         1.0        2.0       0.0       0.0       3.0       0.0
# 5   1.0   0.0         1.0        2.0       0.0       1.0       4.0       6.0
# 6   0.0   0.0         1.0        2.0       0.0       1.0       4.0       0.0
# 7   0.0   3.0         2.0        2.0       0.0       0.0       1.0       2.0
# 8   1.0   0.0         1.0        2.0       0.0       1.0       2.0       0.0
# 9   0.0   0.0         1.0        2.0       0.0       1.0       5.0       0.0
#
#      G1    G2    G3  Average  approved
# 0   0.0  11.0  11.0      7.0       0.0
# 1   9.0  11.0  11.0     10.0       0.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
base['Average'].plot.kde();

# %%
base.approved.value_counts().plot.bar();

# %%
X = base.drop('approved',axis=1)
y = base.approved

# %%
# KNN
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(X, y)
neigh.score(X, y)
# Out:
# 0.987673343605547

# %%
# Decision Tree
clfArvore = tree.DecisionTreeClassifier(random_state=0)
clfArvore = clfArvore.fit(X, y)
clfArvore.score(X,y)
# Out:
# 1.0

# %%
# Linear Regression
clfLog = LogisticRegression(random_state=0,max_iter=1000).fit(X, y)
clfLog.score(X,y)
# Out:
# 1.0

# %%
X_train = base.drop('approved',axis=1)
y_train = base.approved

# %%
X_test = base.drop('approved',axis=1)
y_test = base.approved

# %%
neight = neigh.fit(X_train, y_train)
clfArvore = clfArvore.fit(X_train, y_train)
clfLog = clfLog.fit(X_train, y_train)

# %%
pred_KNN = neigh.predict(X_test)
pred_Arvore = clfArvore.predict(X_test)
pred_Log = clfLog.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
# Acuracy
print(accuracy_score(y_test,pred_KNN))
print(accuracy_score(y_test,pred_Arvore))
print(accuracy_score(y_test,pred_Log))
# Out:
# 0.987673343605547
# 1.0
# 1.0

# %%
# Precision
print(precision_score(y_test,pred_KNN))
print(precision_score(y_test,pred_Arvore))
print(precision_score(y_test,pred_Log))
# Out:
# 0.9875
# 1.0
# 1.0

# %%
# Recall
print(recall_score(y_test,pred_KNN))
print(recall_score(y_test,pred_Arvore))
print(recall_score(y_test,pred_Log))
# Out:
# 0.9186046511627907
# 1.0
# 1.0

# %%
base.to_csv('Student_Performance_results.csv')
print('File created with sucess!')
# Out:
# File created with sucess!
